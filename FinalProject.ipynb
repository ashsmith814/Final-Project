# %% [markdown]
# # Best Neighborhood in Pittsburgh
#
# ## Team Name
#
# ### Introduction

# %% [markdown]
# For this project we were asked to dtermine the best neighborhood in Pittsburgh using diferent datasets from the Western Pennsylvania Regional Data Center (WPRDC).

# %% [markdown]
# ### Metric

# %% [markdown]
# The metric we decided to use in order to measure "bestness" is Community Engagement Score. The metric reflects how safe, lively, and involved a neighborhood is based on the submetrics from the following three datasets:

# %% [markdown]
# #### Monthly Crime Activity

# %% [markdown]
# We used the Monthly Crime Activity dataset for security. We determined the area's crime rate using a population of 100,000 in order to allow for a fair comparison of neighborhoods with varying densities. For this part of the metric, neighborhoods with comparatively low crime rates relative to their population were ranked higher. To prevent outlier analysis, neighborhoods with fewer than 200 residents were excluded.

# %% [markdown]
# #### Community Center Attendance

# %%
fff

# %% [markdown]
# #### City Pool Activity

# %%
ffff

# %% [markdown]
# ### The Best Neighborhood

# %% [markdown]
# ### Conclusion
